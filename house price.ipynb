# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Pune_property_data.csv')
df
# Out:
#        Unnamed: 0                      additionalrooms          age  \
# 0               0                                  NaN  2 - 3 years
# 1               1                                  NaN   0 - 1 year
# 2               2                                  NaN   0 - 1 year
# 3               3                                  NaN  2 - 3 years
# 4               4                                  NaN   0 - 1 year
# ...           ...                                  ...          ...
# 37534       37534                1 rooms( pooja room )   0 - 1 year
# 37535       37535                1 rooms( pooja room )          NaN
# 37536       37536                1 rooms( pooja room )          NaN
# 37537       37537                1 rooms( pooja room )          NaN
# 37538       37538  2 rooms( servant room, pooja room )          NaN
#
#                                       amenitiesavailable  \
# 0      Lift Available,Car Parking,Power Backup,Indoor...
# ...

# %%
df['neworold'].unique()
# Out:
# array(['New', 'Resale', 'neworold', nan], dtype=object)

# %%
df['neworold'].value_counts()
# Out:
# neworold
# Resale      25860
# New         11656
# neworold       22
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37539 entries, 0 to 37538
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          37539 non-null  int64
#  1   additionalrooms     9321 non-null   object
#  2   age                 27637 non-null  object
#  3   amenitiesavailable  34445 non-null  object
#  4   amenitiesnot        34286 non-null  object
#  5   area                37518 non-null  object
#  6   balconies           21911 non-null  object
#  7   bathroom            34667 non-null  object
#  8   bhk                 37538 non-null  object
#  9   carpetarea          8622 non-null   object
#  10  facing              30919 non-null  object
#  11  floor               31919 non-null  object
#  12  locality            37538 non-null  object
#  13  neworold            37538 non-null  object
#  14  opensides           11605 non-null  object
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0
# count  37539.000000
# mean   18769.000000
# std    10836.720214
# min        0.000000
# 25%     9384.500000
# 50%    18769.000000
# 75%    28153.500000
# max    37538.000000

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    Unnamed: 0 additionalrooms          age  \
# 0           0             NaN  2 - 3 years
# 1           1             NaN   0 - 1 year
# 2           2             NaN   0 - 1 year
# 3           3             NaN  2 - 3 years
# 4           4             NaN   0 - 1 year
#
#                                   amenitiesavailable  \
# 0  Lift Available,Car Parking,Power Backup,Indoor...
# 1  Lift Available,Car Parking,Power Backup,24 X 7...
# 2  Lift Available,Car Parking,Power Backup,24 X 7...
# 3  Lift Available,Car Parking,Power Backup,24 X 7...
# 4  Lift Available,Car Parking,Power Backup,24 X 7...
#
#                                         amenitiesnot         area balconies  \
# 0  24 X 7 Security,Children's play area,Club Hous...  1,611 sq ft         2
# 1  Children's play area,Sports Facility,Landscape...  1,279 sq ft       NaN
# 2                                    Sports Facility    670 sq ft       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37539 entries, 0 to 37538
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          37539 non-null  int64
#  1   additionalrooms     9321 non-null   object
#  2   age                 27637 non-null  object
#  3   amenitiesavailable  34445 non-null  object
#  4   amenitiesnot        34286 non-null  object
#  5   area                37518 non-null  object
#  6   balconies           21911 non-null  object
#  7   bathroom            34667 non-null  object
#  8   bhk                 37538 non-null  object
#  9   carpetarea          8622 non-null   object
#  10  facing              30919 non-null  object
#  11  floor               31919 non-null  object
#  12  locality            37538 non-null  object
#  13  neworold            37538 non-null  object
#  14  opensides           11605 non-null  object
# ...

# %%
df.drop(columns=['Unnamed: 0','additionalrooms','carpetarea','opensides','facing','totalfloor','overlooking','projectname','possesiondate','roadfaceing'],inplace=True)

# %%
df
# Out:
#                age                                 amenitiesavailable  \
# 0      2 - 3 years  Lift Available,Car Parking,Power Backup,Indoor...
# 1       0 - 1 year  Lift Available,Car Parking,Power Backup,24 X 7...
# 2       0 - 1 year  Lift Available,Car Parking,Power Backup,24 X 7...
# 3      2 - 3 years  Lift Available,Car Parking,Power Backup,24 X 7...
# 4       0 - 1 year  Lift Available,Car Parking,Power Backup,24 X 7...
# ...            ...                                                ...
# 37534   0 - 1 year  Lift Available,Car Parking,Power Backup,24 X 7...
# 37535          NaN  Lift Available,Car Parking,Power Backup,24 X 7...
# 37536          NaN  Lift Available,Car Parking,Power Backup,24 X 7...
# 37537          NaN  Lift Available,Car Parking,Power Backup,24 X 7...
# 37538          NaN  Lift Available,Car Parking,Power Backup,24 X 7...
#
#                                             amenitiesnot         area  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37539 entries, 0 to 37538
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 27637 non-null  object
#  1   amenitiesavailable  34445 non-null  object
#  2   amenitiesnot        34286 non-null  object
#  3   area                37518 non-null  object
#  4   balconies           21911 non-null  object
#  5   bathroom            34667 non-null  object
#  6   bhk                 37538 non-null  object
#  7   floor               31919 non-null  object
#  8   locality            37538 non-null  object
#  9   neworold            37538 non-null  object
#  10  ownership           28156 non-null  object
#  11  price               37538 non-null  object
#  12  pricepersquare      37538 non-null  object
#  13  status              36078 non-null  object
# dtypes: object(14)
# memory usage: 4.0+ MB

# %% [markdown]
# # Feature Engineering and Data Cleaning

# %%
df.dropna(inplace=True, subset=['age','floor','ownership','amenitiesnot','amenitiesavailable','area','bathroom'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17074 entries, 0 to 37534
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 17074 non-null  object
#  1   amenitiesavailable  17074 non-null  object
#  2   amenitiesnot        17074 non-null  object
#  3   area                17074 non-null  object
#  4   balconies           9758 non-null   object
#  5   bathroom            17074 non-null  object
#  6   bhk                 17074 non-null  object
#  7   floor               17074 non-null  object
#  8   locality            17074 non-null  object
#  9   neworold            17074 non-null  object
#  10  ownership           17074 non-null  object
#  11  price               17074 non-null  object
#  12  pricepersquare      17074 non-null  object
#  13  status              17074 non-null  object
# dtypes: object(14)
# memory usage: 2.0+ MB

# %%
df.reset_index(inplace=True)
df['age'].unique()
# Out:
# array(['2 - 3 years', '0 - 1 year', '1 - 2 years', '1 year', '6 years',
#        '12 years', '2 years', '7 years', '5 - 6 years', '20 years',
#        '7 - 8 years', '20 - 21 years', '9 - 10 years', '13 - 14 years',
#        '19 - 20 years', '14 - 15 years', '15 years', '17 - 18 years',
#        '17 years', '8 - 9 years', '10 - 11 years', '19 years', '25 years',
#        '30 years', '3 years', '6 - 7 years', '4 - 5 years',
#        '11 - 12 years', '3 - 4 years', '26 - 27 years', '11 years',
#        '21 - 22 years', '12 - 13 years', '18 - 19 years', '28 - 29 years',
#        '5 years', '4 years', '16 - 17 years', '9 years', 'age',
#        '10 years', '8 years', '15 - 16 years', '13 years',
#        '22 - 23 years', '18 years', '21 years', '22 years', '16 years',
#        '14 years', '25 - 26 years', '37 - 38 years', '24 - 25 years',
#        '35 - 36 years', '29 - 30 years', '41 - 42 years', '42 years',
#        '30 - 31 years', '33 - 34 years', '23 years', '27 years',
# ...

# %%
df.drop(columns=['index'],inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17074 entries, 0 to 17073
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 17074 non-null  object
#  1   amenitiesavailable  17074 non-null  object
#  2   amenitiesnot        17074 non-null  object
#  3   area                17074 non-null  object
#  4   balconies           9758 non-null   object
#  5   bathroom            17074 non-null  object
#  6   bhk                 17074 non-null  object
#  7   floor               17074 non-null  object
#  8   locality            17074 non-null  object
#  9   neworold            17074 non-null  object
#  10  ownership           17074 non-null  object
#  11  price               17074 non-null  object
#  12  pricepersquare      17074 non-null  object
#  13  status              17074 non-null  object
# dtypes: object(14)
# memory usage: 1.8+ MB

# %%
df.head()
# Out:
#            age                                 amenitiesavailable  \
# 0  2 - 3 years  Lift Available,Car Parking,Power Backup,Indoor...
# 1   0 - 1 year  Lift Available,Car Parking,Power Backup,24 X 7...
# 2   0 - 1 year  Lift Available,Car Parking,Power Backup,24 X 7...
# 3  2 - 3 years  Lift Available,Car Parking,Power Backup,24 X 7...
# 4   0 - 1 year  Lift Available,Car Parking,Power Backup,24 X 7...
#
#                                         amenitiesnot         area balconies  \
# 0  24 X 7 Security,Children's play area,Club Hous...  1,611 sq ft         2
# 1  Children's play area,Sports Facility,Landscape...  1,279 sq ft       NaN
# 2                                    Sports Facility    670 sq ft       NaN
# 3                 Sports Facility,Landscaped Gardens    956 sq ft       NaN
# 4  Club House,Swimming Pool,Sports Facility,Joggi...  1,706 sq ft         1
#
#   bathroom               bhk floor         locality neworold  \
# ...

# %%
# age
df['age'].unique()
df['age']=df['age'].apply(str).str.replace('age','')
df['age']=df['age'].apply(str).str.replace('years','')
df['age']=df['age'].apply(str).str.replace('year','')
df['age']=df['age'].apply(str).str.replace('-','')
df['age']=df['age'].str.split(" ").str.slice(0,1).str.join('')
df['age'].unique()
# Out:
# array(['2', '0', '1', '6', '12', '7', '5', '20', '9', '13', '19', '14',
#        '15', '17', '8', '10', '25', '30', '3', '4', '11', '26', '21',
#        '18', '28', '16', '', '22', '37', '24', '35', '29', '41', '42',
#        '33', '23', '27'], dtype=object)

# %%
# df['age']=pd.to_numeric(df['age'])
df=df[df['age']!='']
df['age']
df['age'].unique()
# Out:
# array(['2', '0', '1', '6', '12', '7', '5', '20', '9', '13', '19', '14',
#        '15', '17', '8', '10', '25', '30', '3', '4', '11', '26', '21',
#        '18', '28', '16', '22', '37', '24', '35', '29', '41', '42', '33',
#        '23', '27'], dtype=object)

# %%
df['age']=df['age'].astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17052 entries, 0 to 17073
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 17052 non-null  int64
#  1   amenitiesavailable  17052 non-null  object
#  2   amenitiesnot        17052 non-null  object
#  3   area                17052 non-null  object
#  4   balconies           9736 non-null   object
#  5   bathroom            17052 non-null  object
#  6   bhk                 17052 non-null  object
#  7   floor               17052 non-null  object
#  8   locality            17052 non-null  object
#  9   neworold            17052 non-null  object
#  10  ownership           17052 non-null  object
#  11  price               17052 non-null  object
#  12  pricepersquare      17052 non-null  object
#  13  status              17052 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 2.0+ MB
# ...

# %%
df.sample(8)
# Out:
#        age                                 amenitiesavailable  \
# 10072   11  Lift Available,Car Parking,Power Backup,24 X 7...
# 16183   10  Lift Available,Car Parking,24 X 7 Security,Chi...
# 362      3  Lift Available,Car Parking,Power Backup,24 X 7...
# 4505    10  Lift Available,Car Parking,Power Backup,24 X 7...
# 4786    10         Lift Available,Car Parking,24 X 7 Security
# 2183     5  Lift Available,Car Parking,Power Backup,24 X 7...
# 11289    6  Lift Available,Car Parking,Power Backup,Vaastu...
# 12417    3  Lift Available,24 X 7 Security,Gymnasium,Swimm...
#
#                                             amenitiesnot         area  \
# 10072  Children's play area,Club House,Gymnasium,Swim...  2,200 sq ft
# 16183  Power Backup,Club House,Gymnasium,Swimming Poo...    605 sq ft
# 362    Children's play area,Club House,Gymnasium,Swim...    945 sq ft
# 4505   Children's play area,Club House,Gymnasium,Spor...  2,359 sq ft
# ...

# %%
# area
df['area'].value_counts()
df['area']=df['area'].apply(str).str.split(' ').str.slice(0,1).str.join('')
df['area']=df['area'].apply(str).str.replace(',','')
df['area']=df['area'].astype('int64')
df['area']
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_7980\1536898625.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area']=df['area'].apply(str).str.split(' ').str.slice(0,1).str.join('')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_7980\1536898625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area']=df['area'].apply(str).str.replace(',','')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_7980\1536898625.py:5: SettingWithCopyWarning:
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17052 entries, 0 to 17073
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 17052 non-null  int64
#  1   amenitiesavailable  17052 non-null  object
#  2   amenitiesnot        17052 non-null  object
#  3   area                17052 non-null  int64
#  4   balconies           9736 non-null   object
#  5   bathroom            17052 non-null  object
#  6   bhk                 17052 non-null  object
#  7   floor               17052 non-null  object
#  8   locality            17052 non-null  object
#  9   neworold            17052 non-null  object
#  10  ownership           17052 non-null  object
#  11  price               17052 non-null  object
#  12  pricepersquare      17052 non-null  object
#  13  status              17052 non-null  object
# dtypes: int64(2), object(12)
# memory usage: 2.0+ MB

# %%
# bathroom
df['bathroom'].unique()
df['bathroom']=df['bathroom'].astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17052 entries, 0 to 17073
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 17052 non-null  int64
#  1   amenitiesavailable  17052 non-null  object
#  2   amenitiesnot        17052 non-null  object
#  3   area                17052 non-null  int64
#  4   balconies           9736 non-null   object
#  5   bathroom            17052 non-null  int64
#  6   bhk                 17052 non-null  object
#  7   floor               17052 non-null  object
#  8   locality            17052 non-null  object
#  9   neworold            17052 non-null  object
#  10  ownership           17052 non-null  object
#  11  price               17052 non-null  object
#  12  pricepersquare      17052 non-null  object
#  13  status              17052 non-null  object
# dtypes: int64(3), object(11)
# memory usage: 2.0+ MB
# ...

# %%
df['bhk'].unique()
# Out:
# array(['3 BHK Apartment ', '2 BHK Apartment ', '1 BHK Apartment ',
#        '4 BHK Apartment ', '5 BHK Villa ', '3 BHK Villa ',
#        '4 BHK Independent House ', '4 BHK Villa ', '1 BHK Villa ',
#        '1 BHK Independent Floor ', '5 BHK Apartment ',
#        '3 BHK Independent House ', '2 BHK Independent House ',
#        '3 BHK Independent Floor ', '2 BHK Villa ',
#        '2 BHK Independent Floor ', '8 BHK Villa ', '6 BHK Apartment ',
#        '1 RK Apartment ', '5 BHK Independent House ',
#        '1 BHK Independent House ', '3 BHK penthouse ',
#        '1 BHK studio apartment ', '2 BHK penthouse ', '4 BHK penthouse ',
#        '5 BHK penthouse ', '6 BHK Villa ', '4 BHK Independent Floor ',
#        '3 BHK Other Residential ', '6 BHK Independent Floor ',
#        '5 BHK Independent Floor ', '4 BHK Other Residential ',
#        '7 BHK Apartment '], dtype=object)

# %%
# bhk
df['bhk'].unique()
df['bhk'].value_counts().plot(kind='bar')
def find(text):
    if text=='1 BHK Apartment ' or text=='2 BHK Apartment ' or text=='3 BHK Apartment ' or text=='4 BHK Apartment ' or text=='5 BHK Apartment ':
        return text
    elif text=='1 BHK Villa ' or text=='2 BHK Villa ' or text=='3 BHK Villa ' or text=='4 BHK Villa ' or text=='5 BHK Villa ':
        return text
    else:
        return 'others'
df['bhk']=df['bhk'].apply(find)
df=df[df['bhk']!='others']
df['bhk'].unique()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_7980\452289606.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bhk']=df['bhk'].apply(find)
# array(['3 BHK Apartment ', '2 BHK Apartment ', '1 BHK Apartment ',
#        '4 BHK Apartment ', '5 BHK Villa ', '3 BHK Villa ', '4 BHK Villa ',
#        '1 BHK Villa ', '5 BHK Apartment ', '2 BHK Villa '], dtype=object)

# %%
df['bhk'].unique()
df['bhk'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bhk'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16630 entries, 0 to 17073
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 16630 non-null  int64
#  1   amenitiesavailable  16630 non-null  object
#  2   amenitiesnot        16630 non-null  object
#  3   area                16630 non-null  int64
#  4   balconies           9389 non-null   object
#  5   bathroom            16630 non-null  int64
#  6   bhk                 16630 non-null  object
#  7   floor               16630 non-null  object
#  8   locality            16630 non-null  object
#  9   neworold            16630 non-null  object
#  10  ownership           16630 non-null  object
#  11  price               16630 non-null  object
#  12  pricepersquare      16630 non-null  object
#  13  status              16630 non-null  object
# dtypes: int64(3), object(11)
# memory usage: 1.9+ MB

# %%
#floor
df['floor'].unique()
df['floor']=df['floor'].apply(str).str.replace('Gr ','0')
df['floor']=df['floor'].apply(str).str.replace('Gr','0')
df['floor']=df['floor'].str.split(',').str.slice(0,1).str.join('')
df['floor']=df['floor'].astype('int64')
df['floor'].unique()
# Out:
# array([ 3,  1,  6,  2,  4, 10, 12,  9, 11,  5,  8, 16, 18,  0,  7, 14, 20,
#        17, 15, 21, 13, 19, 22, 27, 32, 34, 26])

# %%
# locality
df.rename(columns={'locality':'place'},inplace=True)
df['place'].unique()
df['place'].value_counts()

# Calculate value counts for Column1
value_counts = df['place'].value_counts()

# Identify categories with value counts less than 10
categories_to_drop = value_counts[value_counts < 50].index

# Drop rows with categories having value counts less than 10
df = df[~df['place'].isin(categories_to_drop)]

# Reset the index if needed
df.reset_index(drop=True, inplace=True)
df['place'].unique()
# df['place'].value_counts()
# Out:
# array(['Kharadi', 'Sus', 'Bavdhan', 'Mundhwa', 'Viman Nagar', 'Baner',
#        'Hinjewadi', 'Kothrud', 'Wanowrie', 'Wakad', 'Undri', 'Balewadi',
#        'Manjari', 'Wagholi', 'Koregaon Park', 'Pashan', 'Kalyani Nagar',
#        'Wadgaon Sheri', 'NIBM Annex Mohammadwadi', 'NIBM', 'Aundh',
#        'Hadapsar', 'Rahatani', 'Kondhwa', 'Vishrantwadi',
#        'Pimple Saudagar', 'Sasane Nagar', 'Boat Club Road', 'Yerawada',
#        'Sangamvadi', 'Bund Garden', 'Lohegaon', 'Shastri Nagar',
#        'Dhanori', 'Tingre Nagar', 'Handewadi', 'Sinhgad Road',
#        'Bibwewadi'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15044 entries, 0 to 15043
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 15044 non-null  int64
#  1   amenitiesavailable  15044 non-null  object
#  2   amenitiesnot        15044 non-null  object
#  3   area                15044 non-null  int64
#  4   balconies           8076 non-null   object
#  5   bathroom            15044 non-null  int64
#  6   bhk                 15044 non-null  object
#  7   floor               15044 non-null  int64
#  8   place               15044 non-null  object
#  9   neworold            15044 non-null  object
#  10  ownership           15044 non-null  object
#  11  price               15044 non-null  object
#  12  pricepersquare      15044 non-null  object
#  13  status              15044 non-null  object
# dtypes: int64(4), object(10)
# memory usage: 1.6+ MB

# %%
# new or old
df['neworold'].unique()
# Out:
# array(['New', 'Resale'], dtype=object)

# %%
# ownership
df['ownership'].unique()
# Out:
# array(['Freehold', 'Co-Operative Society', 'Power of Attorney',
#        'Leasehol'], dtype=object)

# %%
# price per square
df['pricepersquare'].value_counts()
df.rename(columns={'pricepersquare': 'price_per_sq'},inplace=True)
df['price_per_sq']=df['price_per_sq'].str.split(' ').str.slice(1,2).str.join('')
df['price_per_sq']=df['price_per_sq'].apply(str).str.replace(',','')
df['price_per_sq']=df['price_per_sq'].apply(str).str.replace('/','')
df.head()
# Out:
#    age                                 amenitiesavailable  \
# 0    0  Lift Available,Car Parking,Power Backup,24 X 7...
# 1    0  Lift Available,Car Parking,Power Backup,24 X 7...
# 2    2  Lift Available,Car Parking,Power Backup,24 X 7...
# 3    0  Lift Available,Car Parking,Power Backup,24 X 7...
# 4    1  Lift Available,Car Parking,Power Backup,24 X 7...
#
#                                         amenitiesnot  area balconies  \
# 0  Children's play area,Sports Facility,Landscape...  1279       NaN
# 1                                    Sports Facility   670       NaN
# 2                 Sports Facility,Landscaped Gardens   956       NaN
# 3        Swimming Pool,Sports Facility,Jogging Track  1015         2
# 4                                    Sports Facility  3725       NaN
#
#    bathroom               bhk  floor        place neworold ownership  \
# 0         2  2 BHK Apartment       1      Kharadi      New  Freehold
# ...

# %%
df['price_per_sq']=df['price_per_sq'].astype('int64')
df['price_per_sq'].unique()
# Out:
# array([ 5950,  6119,  6000, ...,  5952, 12244,  6045])

# %%
#status
df['status'].unique()
def extract(text):
    if text=='Ready to move,Unfurnished':
        return 'Unfurnished'
    elif text=='Ready to move,Semi-Furnished':
        return 'Semi-Furnished'
    elif text=='Ready to move,Furnished':
        return 'Furnished'
    else:
        return 'Ready to move'
df['status']=df['status'].apply(extract)
df['status'].unique()
# Out:
# array(['Ready to move', 'Unfurnished', 'Semi-Furnished', 'Furnished'],
#       dtype=object)

# %%
df['status'].value_counts()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15044 entries, 0 to 15043
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 15044 non-null  int64
#  1   amenitiesavailable  15044 non-null  object
#  2   amenitiesnot        15044 non-null  object
#  3   area                15044 non-null  int64
#  4   balconies           8076 non-null   object
#  5   bathroom            15044 non-null  int64
#  6   bhk                 15044 non-null  object
#  7   floor               15044 non-null  int64
#  8   place               15044 non-null  object
#  9   neworold            15044 non-null  object
#  10  ownership           15044 non-null  object
#  11  price               15044 non-null  object
#  12  price_per_sq        15044 non-null  int64
#  13  status              15044 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
#price
df['price'].unique()
df['price']=df['price'].astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15044 entries, 0 to 15043
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 15044 non-null  int64
#  1   amenitiesavailable  15044 non-null  object
#  2   amenitiesnot        15044 non-null  object
#  3   area                15044 non-null  int64
#  4   balconies           8076 non-null   object
#  5   bathroom            15044 non-null  int64
#  6   bhk                 15044 non-null  object
#  7   floor               15044 non-null  int64
#  8   place               15044 non-null  object
#  9   neworold            15044 non-null  object
#  10  ownership           15044 non-null  object
#  11  price               15044 non-null  int64
#  12  price_per_sq        15044 non-null  int64
#  13  status              15044 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 1.6+ MB

# %%
# balcony
df['balconies'].value_counts()
# Calculate value counts for Column1
value_counts = df['balconies'].value_counts()

# Identify categories with value counts less than 10
categories_to_drop = value_counts[value_counts < 135].index

# Drop rows with categories having value counts less than 10
df = df[~df['balconies'].isin(categories_to_drop)]

# Reset the index if needed
df.reset_index(drop=True, inplace=True)
df['balconies'].unique()
# Out:
# array([nan, '2', '1', '3'], dtype=object)

# %%
df['balconies']=df['balconies'].fillna(2)
df['balconies'].value_counts()
df['balconies']=df['balconies'].astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14897 entries, 0 to 14896
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 14897 non-null  int64
#  1   amenitiesavailable  14897 non-null  object
#  2   amenitiesnot        14897 non-null  object
#  3   area                14897 non-null  int64
#  4   balconies           14897 non-null  int64
#  5   bathroom            14897 non-null  int64
#  6   bhk                 14897 non-null  object
#  7   floor               14897 non-null  int64
#  8   place               14897 non-null  object
#  9   neworold            14897 non-null  object
#  10  ownership           14897 non-null  object
#  11  price               14897 non-null  int64
#  12  price_per_sq        14897 non-null  int64
#  13  status              14897 non-null  object
# dtypes: int64(7), object(7)
# memory usage: 1.6+ MB

# %% [markdown]
# # Feature construction

# %%
# amenitiesavailable
df['amenitiesavailable'].unique()
df['amenitiesavailable'].value_counts()
df['lift_avail']=df['amenitiesavailable'].apply(lambda x: 'yes' if 'Lift Available' in x else 'no' )
df['car_parking_avail']=df['amenitiesavailable'].apply(lambda x: 'yes' if 'Car Parking' in x else 'no')
df['Gas_conn_avail']=df['amenitiesavailable'].apply(lambda x: 'yes' if 'Gas connection' in x else 'no' )
df['lift_avail'].value_counts()
df['car_parking_avail'].value_counts()
df['Gas_conn_avail'].value_counts()
# Out:
# Gas_conn_avail
# no     12856
# yes     2041
# Name: count, dtype: int64

# %%
df.drop(columns=['amenitiesavailable'],inplace=True)
df
# Out:
#        age                                       amenitiesnot  area  \
# 0        0  Children's play area,Sports Facility,Landscape...  1279
# 1        0                                    Sports Facility   670
# 2        2                 Sports Facility,Landscaped Gardens   956
# 3        0        Swimming Pool,Sports Facility,Jogging Track  1015
# 4        1                                    Sports Facility  3725
# ...    ...                                                ...   ...
# 14892    0  Children's play area,Club House,Gymnasium,Spor...  2800
# 14893    0  Children's play area,Club House,Gymnasium,Spor...  1660
# 14894    0  Children's play area,Club House,Gymnasium,Spor...  1660
# 14895    0  Children's play area,Club House,Gymnasium,Spor...  1084
# 14896    0  Children's play area,Club House,Gymnasium,Spor...  1084
#
#        balconies  bathroom               bhk  floor        place neworold  \
# 0              2         2  2 BHK Apartment       1      Kharadi      New
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14897 entries, 0 to 14896
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                14897 non-null  int64
#  1   amenitiesnot       14897 non-null  object
#  2   area               14897 non-null  int64
#  3   balconies          14897 non-null  int64
#  4   bathroom           14897 non-null  int64
#  5   bhk                14897 non-null  object
#  6   floor              14897 non-null  int64
#  7   place              14897 non-null  object
#  8   neworold           14897 non-null  object
#  9   ownership          14897 non-null  object
#  10  price              14897 non-null  int64
#  11  price_per_sq       14897 non-null  int64
#  12  status             14897 non-null  object
#  13  lift_avail         14897 non-null  object
#  14  car_parking_avail  14897 non-null  object
#  15  Gas_conn_avail     14897 non-null  object
# ...

# %%
# amenitiesnot
df.drop(columns=['amenitiesnot'],inplace=True)
df
# Out:
#        age  area  balconies  bathroom               bhk  floor        place  \
# 0        0  1279          2         2  2 BHK Apartment       1      Kharadi
# 1        0   670          2         1  1 BHK Apartment       1          Sus
# 2        2   956          2         2  2 BHK Apartment       1      Bavdhan
# 3        0  1015          2         2  2 BHK Apartment       2      Mundhwa
# 4        1  3725          2         5  4 BHK Apartment       1  Viman Nagar
# ...    ...   ...        ...       ...               ...    ...          ...
# 14892    0  2800          2         4  4 BHK Apartment       5      Bavdhan
# 14893    0  1660          2         3  3 BHK Apartment       7        Baner
# 14894    0  1660          2         3  3 BHK Apartment       5     Balewadi
# 14895    0  1084          1         2  2 BHK Apartment       4        Baner
# 14896    0  1084          1         2  2 BHK Apartment       6        Baner
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14897 entries, 0 to 14896
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                14897 non-null  int64
#  1   area               14897 non-null  int64
#  2   balconies          14897 non-null  int64
#  3   bathroom           14897 non-null  int64
#  4   bhk                14897 non-null  object
#  5   floor              14897 non-null  int64
#  6   place              14897 non-null  object
#  7   neworold           14897 non-null  object
#  8   ownership          14897 non-null  object
#  9   price              14897 non-null  int64
#  10  price_per_sq       14897 non-null  int64
#  11  status             14897 non-null  object
#  12  lift_avail         14897 non-null  object
#  13  car_parking_avail  14897 non-null  object
#  14  Gas_conn_avail     14897 non-null  object
# dtypes: int64(7), object(8)
# memory usage: 1.7+ MB

# %%
df['neworold'].value_counts()
# Out:
# neworold
# Resale    12998
# New        1899
# Name: count, dtype: int64

# %% [markdown]
# # charts and stats

# %%
df.describe()
# Out:
#                 age          area     balconies      bathroom         floor  \
# count  14897.000000  14897.000000  14897.000000  14897.000000  14897.000000
# mean       6.478955   1697.744445      1.853393      2.562194      4.497147
# std        4.367851   1103.709622      0.520770      1.046792      3.129544
# min        0.000000    270.000000      1.000000      1.000000      0.000000
# 25%        3.000000   1015.000000      2.000000      2.000000      2.000000
# 50%        6.000000   1350.000000      2.000000      2.000000      4.000000
# 75%       10.000000   2000.000000      2.000000      3.000000      6.000000
# max       42.000000  19000.000000      3.000000      8.000000     34.000000
#
#               price  price_per_sq
# count  1.489700e+04  14897.000000
# mean   1.591557e+07   8286.783983
# std    1.729161e+07   3498.342607
# min    4.700000e+05    705.000000
# 25%    6.500000e+06   5925.000000
# 50%    9.600000e+06   7317.000000
# 75%    1.800000e+07  10000.000000
# ...

# %% [markdown]
# # univariate

# %%
df.head()
# Out:
#    age  area  balconies  bathroom               bhk  floor        place  \
# 0    0  1279          2         2  2 BHK Apartment       1      Kharadi
# 1    0   670          2         1  1 BHK Apartment       1          Sus
# 2    2   956          2         2  2 BHK Apartment       1      Bavdhan
# 3    0  1015          2         2  2 BHK Apartment       2      Mundhwa
# 4    1  3725          2         5  4 BHK Apartment       1  Viman Nagar
#
#   neworold ownership     price  price_per_sq         status lift_avail  \
# 0      New  Freehold   7610050          5950  Ready to move        yes
# 1      New  Freehold   4100000          6119  Ready to move        yes
# 2      New  Freehold   5736000          6000  Ready to move        yes
# 3      New  Freehold   4720765          4651  Ready to move        yes
# 4      New  Freehold  30172500          8100  Ready to move        yes
#
#   car_parking_avail Gas_conn_avail
# 0               yes             no
# ...

# %%
df['age'].value_counts()
df['age'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='age'>

# %%
df=df[df['age']<=20]

# %%
df['age'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='age'>

# %%
df['age'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# area
df['area'].value_counts()
# Out:
# area
# 1100    285
# 1050    237
# 1500    236
# 1600    235
# 1150    225
#        ...
# 1091      1
# 1852      1
# 1116      1
# 3090      1
# 2054      1
# Name: count, Length: 1599, dtype: int64

# %%
#balcon
df['balconies'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='balconies'>

# %%
df['balconies'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#bathrooms
df['bathroom'].value_counts().plot(kind='bar')
df=df[df['bathroom']<=5]

# %%
df['bathroom'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bathroom'>

# %%
df['bathroom'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# bhk
df['bhk'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bhk'>

# %%
df['bathroom'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#floor
df['floor'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='floor'>

# %%
df['floor'].value_counts().plot(kind='pie', autopct='%1.1f%%', xlabel='floor')
# Out:
# <Axes: ylabel='count'>

# %%
# neworold
df['neworold'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='neworold'>

# %%
df['neworold'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#ownership
df['ownership'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ownership'>

# %%
df['ownership'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# status
df['status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='status'>

# %%
df['status'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df
# Out:
#        age  area  balconies  bathroom               bhk  floor        place  \
# 0        0  1279          2         2  2 BHK Apartment       1      Kharadi
# 1        0   670          2         1  1 BHK Apartment       1          Sus
# 2        2   956          2         2  2 BHK Apartment       1      Bavdhan
# 3        0  1015          2         2  2 BHK Apartment       2      Mundhwa
# 4        1  3725          2         5  4 BHK Apartment       1  Viman Nagar
# ...    ...   ...        ...       ...               ...    ...          ...
# 14892    0  2800          2         4  4 BHK Apartment       5      Bavdhan
# 14893    0  1660          2         3  3 BHK Apartment       7        Baner
# 14894    0  1660          2         3  3 BHK Apartment       5     Balewadi
# 14895    0  1084          1         2  2 BHK Apartment       4        Baner
# 14896    0  1084          1         2  2 BHK Apartment       6        Baner
#
# ...

# %%
# lift availble
df['lift_avail'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='lift_avail'>

# %%
df['lift_avail'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#car parking availble
df['car_parking_avail'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='car_parking_avail'>

# %%
df['car_parking_avail'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# gas connection
df['Gas_conn_avail'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gas_conn_avail'>

# %%
df['Gas_conn_avail'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df
# Out:
#        age  area  balconies  bathroom               bhk  floor        place  \
# 0        0  1279          2         2  2 BHK Apartment       1      Kharadi
# 1        0   670          2         1  1 BHK Apartment       1          Sus
# 2        2   956          2         2  2 BHK Apartment       1      Bavdhan
# 3        0  1015          2         2  2 BHK Apartment       2      Mundhwa
# 4        1  3725          2         5  4 BHK Apartment       1  Viman Nagar
# ...    ...   ...        ...       ...               ...    ...          ...
# 14892    0  2800          2         4  4 BHK Apartment       5      Bavdhan
# 14893    0  1660          2         3  3 BHK Apartment       7        Baner
# 14894    0  1660          2         3  3 BHK Apartment       5     Balewadi
# 14895    0  1084          1         2  2 BHK Apartment       4        Baner
# 14896    0  1084          1         2  2 BHK Apartment       6        Baner
#
# ...

# %% [markdown]
# # bivariate analysis

# %%
# between balconies and price
sns.barplot(x=df['balconies'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# bathroom and price
sns.barplot(x=df['bathroom'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# between bhk and price
sns.barplot(x=df['bhk'],y=df['price'], estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
# between floor and price
sns.barplot(x=df['floor'],y=df['price'],estimator=np.mean)
plt.xticks(rotation='vertical')
plt.show()

# %%
# between place and price
sns.barplot(x=df['place'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# between neworold and price
sns.barplot(x=df['neworold'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
# between ownership and price
sns.barplot(x=df['ownership'],y=df['price'], estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df
# Out:
#        age  area  balconies  bathroom               bhk  floor        place  \
# 0        0  1279          2         2  2 BHK Apartment       1      Kharadi
# 1        0   670          2         1  1 BHK Apartment       1          Sus
# 2        2   956          2         2  2 BHK Apartment       1      Bavdhan
# 3        0  1015          2         2  2 BHK Apartment       2      Mundhwa
# 4        1  3725          2         5  4 BHK Apartment       1  Viman Nagar
# ...    ...   ...        ...       ...               ...    ...          ...
# 14892    0  2800          2         4  4 BHK Apartment       5      Bavdhan
# 14893    0  1660          2         3  3 BHK Apartment       7        Baner
# 14894    0  1660          2         3  3 BHK Apartment       5     Balewadi
# 14895    0  1084          1         2  2 BHK Apartment       4        Baner
# 14896    0  1084          1         2  2 BHK Apartment       6        Baner
#
# ...

# %%
# between status and price
sns.barplot(x=df['status'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
# between lift_avail and price
sns.barplot(x=df['lift_avail'],y=df['price'], estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
# between car_parking_avail and price
sns.barplot(x=df['car_parking_avail'],y=df['price'], estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
# between gas_conn_avail and price
sns.barplot(x=df['Gas_conn_avail'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # feature transformation

# %%
df.head()
df['neworold'].unique()
# Out:
# array(['New', 'Resale'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14733 entries, 0 to 14896
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                14733 non-null  int64
#  1   area               14733 non-null  int64
#  2   balconies          14733 non-null  int64
#  3   bathroom           14733 non-null  int64
#  4   bhk                14733 non-null  object
#  5   floor              14733 non-null  int64
#  6   place              14733 non-null  object
#  7   neworold           14733 non-null  object
#  8   ownership          14733 non-null  object
#  9   price              14733 non-null  int64
#  10  price_per_sq       14733 non-null  int64
#  11  status             14733 non-null  object
#  12  lift_avail         14733 non-null  object
#  13  car_parking_avail  14733 non-null  object
#  14  Gas_conn_avail     14733 non-null  object
# dtypes: int64(7), object(8)
# memory usage: 1.8+ MB

# %%
df.head()
# Out:
#    age  area  balconies  bathroom               bhk  floor        place  \
# 0    0  1279          2         2  2 BHK Apartment       1      Kharadi
# 1    0   670          2         1  1 BHK Apartment       1          Sus
# 2    2   956          2         2  2 BHK Apartment       1      Bavdhan
# 3    0  1015          2         2  2 BHK Apartment       2      Mundhwa
# 4    1  3725          2         5  4 BHK Apartment       1  Viman Nagar
#
#   neworold ownership     price  price_per_sq         status lift_avail  \
# 0      New  Freehold   7610050          5950  Ready to move        yes
# 1      New  Freehold   4100000          6119  Ready to move        yes
# 2      New  Freehold   5736000          6000  Ready to move        yes
# 3      New  Freehold   4720765          4651  Ready to move        yes
# 4      New  Freehold  30172500          8100  Ready to move        yes
#
#   car_parking_avail Gas_conn_avail
# 0               yes             no
# ...

# %%
temp=df.drop(columns=['age','area','balconies','bathroom','bhk','floor','price','price_per_sq','place'])
temp2=temp.copy()
temp
# Out:
#       neworold ownership         status lift_avail car_parking_avail  \
# 0          New  Freehold  Ready to move        yes               yes
# 1          New  Freehold  Ready to move        yes               yes
# 2          New  Freehold  Ready to move        yes               yes
# 3          New  Freehold  Ready to move        yes               yes
# 4          New  Freehold  Ready to move        yes               yes
# ...        ...       ...            ...        ...               ...
# 14892      New  Freehold  Ready to move        yes               yes
# 14893      New  Freehold  Ready to move        yes               yes
# 14894      New  Freehold  Ready to move        yes               yes
# 14895      New  Freehold  Ready to move        yes               yes
# 14896      New  Freehold  Ready to move        yes               yes
#
#       Gas_conn_avail
# 0                 no
# 1                 no
# 2                 no
# 3                 no
# 4                 no
# ...

# %%
df.drop(columns=['ownership','status','lift_avail','car_parking_avail','Gas_conn_avail','neworold'],inplace=True)
df
# Out:
#        age  area  balconies  bathroom               bhk  floor        place  \
# 0        0  1279          2         2  2 BHK Apartment       1      Kharadi
# 1        0   670          2         1  1 BHK Apartment       1          Sus
# 2        2   956          2         2  2 BHK Apartment       1      Bavdhan
# 3        0  1015          2         2  2 BHK Apartment       2      Mundhwa
# 4        1  3725          2         5  4 BHK Apartment       1  Viman Nagar
# ...    ...   ...        ...       ...               ...    ...          ...
# 14892    0  2800          2         4  4 BHK Apartment       5      Bavdhan
# 14893    0  1660          2         3  3 BHK Apartment       7        Baner
# 14894    0  1660          2         3  3 BHK Apartment       5     Balewadi
# 14895    0  1084          1         2  2 BHK Apartment       4        Baner
# 14896    0  1084          1         2  2 BHK Apartment       6        Baner
#
#           price  price_per_sq
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(categories=[['Resale','New'],['Leasehol','Power of Attorney','Co-Operative Society','Freehold'],['Unfurnished','Semi-Furnished','Furnished','Ready to move'],['no','yes'], ['no','yes'], ['no','yes']])
temp=oe.fit_transform(temp)
temp
# Out:
# array([[1., 3., 3., 1., 1., 0.],
#        [1., 3., 3., 1., 1., 0.],
#        [1., 3., 3., 1., 1., 0.],
#        ...,
#        [1., 3., 3., 1., 1., 0.],
#        [1., 3., 3., 1., 1., 0.],
#        [1., 3., 3., 1., 1., 0.]])

# %%
# Convert the encoded NumPy array back to a DataFrame with original columns and index
temp2
temp= pd.DataFrame(temp, columns=temp2.columns, index=temp2.index)
temp.head()
# Out:
#    neworold  ownership  status  lift_avail  car_parking_avail  Gas_conn_avail
# 0       1.0        3.0     3.0         1.0                1.0             0.0
# 1       1.0        3.0     3.0         1.0                1.0             0.0
# 2       1.0        3.0     3.0         1.0                1.0             0.0
# 3       1.0        3.0     3.0         1.0                1.0             0.0
# 4       1.0        3.0     3.0         1.0                1.0             0.0

# %% [markdown]
# # merging two dataframe temp and df

# %%
df.info()
# temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14733 entries, 0 to 14896
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           14733 non-null  int64
#  1   area          14733 non-null  int64
#  2   balconies     14733 non-null  int64
#  3   bathroom      14733 non-null  int64
#  4   bhk           14733 non-null  object
#  5   floor         14733 non-null  int64
#  6   place         14733 non-null  object
#  7   price         14733 non-null  int64
#  8   price_per_sq  14733 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 1.1+ MB

# %%
# adding a new column named id
n=len(df)
df['id']=range(n)
temp['id']=range(n)
df.reset_index(inplace=True, drop=True)
temp.reset_index(inplace=True, drop=True)
temp.info()
df= pd.merge(df, temp, on='id')
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14733 entries, 0 to 14732
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   neworold           14733 non-null  float64
#  1   ownership          14733 non-null  float64
#  2   status             14733 non-null  float64
#  3   lift_avail         14733 non-null  float64
#  4   car_parking_avail  14733 non-null  float64
#  5   Gas_conn_avail     14733 non-null  float64
#  6   id                 14733 non-null  int64
# dtypes: float64(6), int64(1)
# memory usage: 805.8 KB
#        age  area  balconies  bathroom               bhk  floor        place  \
# 0        0  1279          2         2  2 BHK Apartment       1      Kharadi
# 1        0   670          2         1  1 BHK Apartment       1          Sus
# 2        2   956          2         2  2 BHK Apartment       1      Bavdhan
# ...

# %% [markdown]
# # corelation and heatmap

# %%
df.drop(columns=['id'], inplace=True)

# %%
new_df=df.drop(columns=['bhk','place'])

# %%
new_df
# Out:
#        age  area  balconies  bathroom  floor     price  price_per_sq  \
# 0        0  1279          2         2      1   7610050          5950
# 1        0   670          2         1      1   4100000          6119
# 2        2   956          2         2      1   5736000          6000
# 3        0  1015          2         2      2   4720765          4651
# 4        1  3725          2         5      1  30172500          8100
# ...    ...   ...        ...       ...    ...       ...           ...
# 14728    0  2800          2         4      5  20000000          7142
# 14729    0  1660          2         3      7  12500000          7530
# 14730    0  1660          2         3      5  12500000          7530
# 14731    0  1084          1         2      4   8363000          7714
# 14732    0  1084          1         2      6   8363000          7714
#
#        neworold  ownership  status  lift_avail  car_parking_avail  \
# 0           1.0        3.0     3.0         1.0                1.0
# ...

# %%
new_df.corr()['price']
# Out:
# age                  0.053807
# area                 0.869914
# balconies            0.224760
# bathroom             0.687352
# floor                0.112935
# price                1.000000
# price_per_sq         0.768433
# neworold            -0.010283
# ownership            0.030190
# status               0.073975
# lift_avail          -0.032792
# car_parking_avail   -0.017561
# Gas_conn_avail       0.085797
# Name: price, dtype: float64

# %%
sns.heatmap(new_df.corr())
# Out:
# <Axes: >

# %% [markdown]
# # model

# %%
df.head()
# Out:
#    age  area  balconies  bathroom               bhk  floor        place  \
# 0    0  1279          2         2  2 BHK Apartment       1      Kharadi
# 1    0   670          2         1  1 BHK Apartment       1          Sus
# 2    2   956          2         2  2 BHK Apartment       1      Bavdhan
# 3    0  1015          2         2  2 BHK Apartment       2      Mundhwa
# 4    1  3725          2         5  4 BHK Apartment       1  Viman Nagar
#
#       price  price_per_sq  neworold  ownership  status  lift_avail  \
# 0   7610050          5950       1.0        3.0     3.0         1.0
# 1   4100000          6119       1.0        3.0     3.0         1.0
# 2   5736000          6000       1.0        3.0     3.0         1.0
# 3   4720765          4651       1.0        3.0     3.0         1.0
# 4  30172500          8100       1.0        3.0     3.0         1.0
#
#    car_parking_avail  Gas_conn_avail
# 0                1.0             0.0
# 1                1.0             0.0
# ...

# %%
df['balconies'].value_counts()
# Out:
# balconies
# 2    10428
# 1     3255
# 3     1050
# Name: count, dtype: int64

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_7980\4207564571.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
# data is skewed so we appl log transformation
sns.distplot(np.log(df['price']))
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_7980\2662162497.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['price']))
# <Axes: xlabel='price', ylabel='Density'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14733 entries, 0 to 14732
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                14733 non-null  int64
#  1   area               14733 non-null  int64
#  2   balconies          14733 non-null  int64
#  3   bathroom           14733 non-null  int64
#  4   bhk                14733 non-null  object
#  5   floor              14733 non-null  int64
#  6   place              14733 non-null  object
#  7   price              14733 non-null  int64
#  8   price_per_sq       14733 non-null  int64
#  9   neworold           14733 non-null  float64
#  10  ownership          14733 non-null  float64
#  11  status             14733 non-null  float64
#  12  lift_avail         14733 non-null  float64
#  13  car_parking_avail  14733 non-null  float64
#  14  Gas_conn_avail     14733 non-null  float64
# dtypes: float64(6), int64(7), object(2)
# ...

# %%
# spliting into two parts
df['price'].dtype
x=df.drop(columns=['price'])
y=np.log(df['price'])

# %%
x
y
# Out:
# 0        15.844980
# 1        15.226498
# 2        15.562273
# 3        15.367481
# 4        17.222441
#            ...
# 14728    16.811243
# 14729    16.341239
# 14730    16.341239
# 14731    15.939328
# 14732    15.939328
# Name: price, Length: 14733, dtype: float64

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
x_train.shape
# Out:
# (11786, 14)

# %%
x_test.shape
# Out:
# (2947, 14)

# %%
y_train.shape
# Out:
# (11786,)

# %%
y_test.shape
# Out:
# (2947,)

# %%
# reshaping y column
y_train=np.array(y_train).reshape(-1,1)
y_test=np.array(y_test).reshape(-1,1)

# %%
y_test.shape
# Out:
# (2947, 1)

# %%
x_train.info()
x_train['neworold']=x_train['neworold'].astype('int64')
x_train['ownership']=x_train['ownership'].astype('int64')
x_train['status']=x_train['status'].astype('int64')
x_train['lift_avail']=x_train['lift_avail'].astype('int64')
x_train['car_parking_avail']=x_train['car_parking_avail'].astype('int64')
x_train['Gas_conn_avail']=x_train['Gas_conn_avail'].astype('int64')
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11786 entries, 2435 to 7270
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                11786 non-null  int64
#  1   area               11786 non-null  int64
#  2   balconies          11786 non-null  int64
#  3   bathroom           11786 non-null  int64
#  4   bhk                11786 non-null  object
#  5   floor              11786 non-null  int64
#  6   place              11786 non-null  object
#  7   price_per_sq       11786 non-null  int64
#  8   neworold           11786 non-null  float64
#  9   ownership          11786 non-null  float64
#  10  status             11786 non-null  float64
#  11  lift_avail         11786 non-null  float64
#  12  car_parking_avail  11786 non-null  float64
#  13  Gas_conn_avail     11786 non-null  float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 1.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# # pipeline

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Linear Regression

# %%
# x_train
# step1=ColumnTransformer([
#     ('col_tnf',OneHotEncoder(sparse_ouptut=False, drop='first'),[4,6])
# ],remainder='passthrough')
# step2=LinearRegression()
# pipe=Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# %% [markdown]
# # Ridge Regression

# %%
# step1=ColumnTransformer([
#     ('col_tnf',OneHotEncoder(sparse_ouptut=False,drop='first'),[4,6])  
# ],remainder='passthrough')
# step2=Ridge(alpha=.6)
# pipe=Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# %% [markdown]
# # Lasso

# %%
# step1=ColumnTransformer([
#     ('col_tnf',OneHotEncoder(sparse_ouptut=False,drop='first'),[4,6])  
# ],remainder='passthrough')
# step2=Lasso(alpha=.5)
# pipe=Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# %% [markdown]
# # support vector machine(svm)

# %%
# from sklearn.svm import SVR
# step1=ColumnTransformer([
#     ('col_tnf',OneHotEncoder(sparse_ouptut=False,drop='first'),[4,6])  
# ],remainder='passthrough')
# step2=SVR(kernel='poly',degree=2)
# pipe=Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# %% [markdown]
# # Decision Tree

# %%
# # from sklearn.tree import DecisionTreeRegressor
# step1=ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[4,6])
# ], remainder='passthrough')

# step2=DecisionTreeRegressor()
# pipe=Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# %% [markdown]
# # Random Forest

# %%
# # from sklearn.ensemble import RandomForestRegressor
# step1=ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[4,6])
# ],remainder='passthrough')

# step2=RandomForestRegressor(n_estimators=200, max_features='log2')
# pipe=Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# %% [markdown]
# # extra tree

# %%
# from sklearn.ensemble import ExtraTreesRegressor
# step1=ColumnTransformer([
#     ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[4,6])
# ],remainder='passthrough')
# step2=ExtraTreesRegressor(n_estimators=165,max_features='sqrt')
# pipe=Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# %% [markdown]
# # Ada boost

# %%
# step1=ColumnTransformer([
#     ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[4,6])
# ],remainder='passthrough')
# step2=AdaBoostingRegressor(learning_rate=.8)
# pipe=Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# %% [markdown]
# # Gradient Boost

# %%
# # from sklearn.ensemble import GradientBoostingRegressor
step1=ColumnTransformer([
    ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[4,6])
],remainder='passthrough')
step2=GradientBoostingRegressor(learning_rate=.6)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
# Out:
# n:\ml-projects\regression\house price predictor\env\lib\site-packages\sklearn\ensemble\_gb.py:672: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?

# %% [markdown]
# # voting (different algo)

# %%
# taking diff model (gradient ,decision tree, random forest, extra tree)
# from sklearn.ensemble import VotingRegressor
# step1=ColumnTransformer([
#     ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[4,6])
# ],remainder='passthrough')
# gb=GradientBoostingRegressor(learning_rate=.6)
# dt=DecisionTreeRegressor()
# rf=RandomForestRegressor(n_estimators=200, max_features='log2')
# et=ExtraTreesRegressor(n_estimators=165,max_features='sqrt')
# estimators=[('gb',gb),('dt',dt),('rf',rf),('et',et)]
# vr=VotingRegressor(estimators=estimators)
# pipe=Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# %% [markdown]
# # voting (same algo gradient boost)

# %%
# from sklearn.ensemble import VotingRegressor
# step1=ColumnTransformer([
#     ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[4,6])
# ],remainder='passthrough')
# gb1=GradientBoostingRegressor(learning_rate=.2)
# gb2=GradientBoostingRegressor(learning_rate=.6)
# # gb3=GradientBoostingRegressor(learning_rate=.7)
# estimators=[('gb1',gb),('gb2',gb2)]
# vr=VotingRegressor(estimators=estimators)
# pipe=Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# %% [markdown]
# # stacking

# %%
# from sklearn.ensemble import StackingRegressor
# step1=ColumnTransformer([
#     ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[4,6])
# ],remainder='passthrough')
# gb=GradientBoostingRegressor(learning_rate=.6)
# dt=DecisionTreeRegressor()
# # rf=RandomForestRegressor(n_estimators=200, max_features='log2')
# et=ExtraTreesRegressor(n_estimators=165,max_features='sqrt')
# estimators=[('gb',gb),('dt',dt),('et',et)]
# vr=StackingRegressor(estimators=estimators, final_estimator=RandomForestRegressor(n_estimators=160, max_features='log2') )
# pipe=Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# %% [markdown]
# # Accuracy of models

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
from sklearn.model_selection import cross_val_score
print(f"mean squared error = {mean_squared_error(y_test,y_pred)}")
# print(f"k cross validation (root_mean_squared error) {np.sqrt(-cross_val_score(pipe,x,y,cv=10, scoring='neg_mean_squared_error'))}")
print(f"mean absolute error= {mean_absolute_error(y_test,y_pred)}")
# print(f"k cross validation (mean absolute_error) {cross_val_score(pipe,x,y,cv=10, scoring='mean_absolute_error')}")
print(f"accuray = {r2_score(y_test,y_pred)}")
# print(f"k cross validation(accuray)= {np.mean(cross_val_score(pipe,x,y,cv=10))}")
# Out:
# mean squared error = 0.0009822867426682062
# mean absolute error= 0.019342778292729113
# accuray = 0.9984246768254806
# k cross validation(accuray)= 0.9980375273950637

# %% [markdown]
# # exporting model

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))

# %%
x_train.head(1)
df.head(1)
# Out:
#    age  area  balconies  bathroom               bhk  floor    place    price  \
# 0    0  1279          2         2  2 BHK Apartment       1  Kharadi  7610050
#
#    price_per_sq  neworold  ownership  status  lift_avail  car_parking_avail  \
# 0          5950       1.0        3.0     3.0         1.0                1.0
#
#    Gas_conn_avail
# 0             0.0
